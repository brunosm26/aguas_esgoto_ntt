# %%
# %sql
SHOW TABLES IN classes.bronze;

# %%
# %sql

SELECT * FROM classes.bronze.meu_csv_raw LIMIT 10;

# %%
# %sql
-- Criando a tabela 'meu_csv_raw' na camada bronze do catálogo 'classes'
CREATE TABLE IF NOT EXISTS classes.bronze.meu_csv_raw
USING CSV
OPTIONS (
  path 'dbfs:/FileStore/tables/consumo_agua.csv',  
  header 'true',  
  inferSchema 'true' 
);
