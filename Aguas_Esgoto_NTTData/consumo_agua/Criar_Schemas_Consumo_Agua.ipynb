# %%
# %sql

CREATE SCHEMA IF NOT EXISTS consumo_agua.bronze;


CREATE SCHEMA IF NOT EXISTS consumo_agua.silver;

CREATE SCHEMA IF NOT EXISTS consumo_agua.gold;

# %%
# %sql

SHOW SCHEMAS IN consumo_agua;
